# %%
import pandas as pd
import os

# %%
# Read in the combined stats file
dirname = os.path.abspath('..')
filename_pkl = dirname + "/data/combined_stats.pkl"
df = pd.read_pickle(filename_pkl)

df.head()
# Out:
#                Fighter  Str  Td  Pass Weight class  Method  Round  Time  KD  \
# 0  Khabib Nurmagomedov   22   7     5  Lightweight     SUB      3  2:06   0
# 1          Paul Felder   56   0     0  Lightweight     DEC      3  5:00   0
# 2      Islam Makhachev   43   0     0  Lightweight     DEC      3  5:00   1
# 3       Curtis Blaydes   25   5     3  Heavyweight  KO/TKO      2  2:22   0
# 4       Diego Ferreira  109   0     0  Lightweight     DEC      3  5:00   0
#
#    Rev.  DK_Points Round_Cat
# 0     0      106.0         3
# 1     0       58.0     3 DEC
# 2     0       61.5     3 DEC
# 3     0      116.5         2
# 4     0       84.5     3 DEC

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1782 entries, 0 to 1785
# Data columns (total 12 columns):
# Fighter         1782 non-null object
# Str             1782 non-null int64
# Td              1782 non-null int64
# Pass            1782 non-null int64
# Weight class    1782 non-null object
# Method          1782 non-null object
# Round           1782 non-null int64
# Time            1782 non-null object
# KD              1782 non-null int64
# Rev.            1782 non-null int64
# DK_Points       1782 non-null float64
# Round_Cat       1782 non-null object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 181.0+ KB

# %%
df.describe()
# Out:
#                Str           Td         Pass        Round           KD  \
# count  1782.000000  1782.000000  1782.000000  1782.000000  1782.000000
# mean     47.786756     1.340629     1.538159     2.431538     0.391134
# std      34.593176     1.886183     2.228258     0.973295     0.632447
# min       0.000000     0.000000     0.000000     1.000000     0.000000
# 25%      21.250000     0.000000     0.000000     2.000000     0.000000
# 50%      42.000000     1.000000     1.000000     3.000000     0.000000
# 75%      67.000000     2.000000     2.000000     3.000000     1.000000
# max     290.000000    12.000000    19.000000     5.000000     5.000000
#
#               Rev.    DK_Points
# count  1782.000000  1782.000000
# mean      0.144220    92.177890
# std       0.435597    22.316003
# min       0.000000    38.500000
# 25%       0.000000    74.000000
# 50%       0.000000    94.000000
# 75%       0.000000   107.875000
# max       5.000000   190.000000

# %% [markdown]
# ## Specific Fighters

# %%
df[df.Fighter=='Jeremy Stephens']
# Out:
#               Fighter  Str  Td  Pass   Weight class  Method  Round  Time  KD  \
# 756   Jeremy Stephens   24   0     0  Featherweight  KO/TKO      2  1:35   1
# 826   Jeremy Stephens   49   0     0  Featherweight  KO/TKO      2  2:36   1
# 994   Jeremy Stephens   96   0     1  Featherweight     DEC      3  5:00   5
# 1593  Jeremy Stephens   55   0     0  Featherweight     DEC      3  5:00   0
#
#       Rev.  DK_Points Round_Cat
# 756      0       92.0         2
# 826      0      104.5         2
# 994      0      131.0     3 DEC
# 1593     0       57.5     3 DEC

# %% [markdown]
# # Stat EDA -- By WEIGHTCLASS

# %%
num_fights = df['Fighter'].value_counts()

# %%
common_fighters = list(num_fights[num_fights>=6].index)

# %%
df_common = df.loc[df.Fighter.isin(common_fighters), :]

# %%
df_common.groupby('Fighter')['DK_Points'].describe().sort_values('mean', ascending=False)
# Out:
#                            count        mean        std    min      25%  \
# Fighter
# Gregor Gillespie             6.0  125.250000  19.001974   99.5  112.250
# Jessica Andrade              7.0  123.714286  17.913815  103.5  112.250
# Max Holloway                 6.0  123.000000  36.928309   87.5   99.625
# Khabib Nurmagomedov          6.0  120.666667  18.584043  105.0  106.125
# Colby Covington              7.0  118.428571  30.448630   74.0  102.000
# Kevin Lee                    6.0  115.916667  34.934820   70.0   95.875
# Donald Cerrone               8.0  114.750000  13.445658   96.5  104.875
# Dustin Poirier               7.0  111.714286  14.893671   89.0  103.500
# Stipe Miocic                 6.0  110.666667   4.045574  105.5  107.750
# Curtis Blaydes               7.0  108.928571  25.386067   66.0   94.750
# Alexander Volkanovski        7.0  108.642857  15.641063   77.5  106.750
# Jack Hermansson              7.0  108.428571  22.559973   80.5   90.750
# ...

# %%
df_common[df_common.Fighter=='Francis Ngannou']
# Out:
#               Fighter  Str  Td  Pass Weight class  Method  Round  Time  KD  \
# 108   Francis Ngannou    9   0     0  Heavyweight  KO/TKO      1  1:11   1
# 305   Francis Ngannou    6   0     0  Heavyweight  KO/TKO      1  0:26   0
# 306   Francis Ngannou    6   0     0  Heavyweight  KO/TKO      1  0:26   1
# 307   Francis Ngannou    6   0     0  Heavyweight  KO/TKO      1  1:42   0
# 308   Francis Ngannou    6   0     0  Heavyweight  KO/TKO      1  1:42   1
# 418   Francis Ngannou   13   0     0  Heavyweight  KO/TKO      1  0:45   1
# 1257  Francis Ngannou    8   0     0  Heavyweight  KO/TKO      1  1:32   1
# 1258  Francis Ngannou    8   0     0  Heavyweight  KO/TKO      1  1:32   0
# 1259  Francis Ngannou    8   0     0  Heavyweight  KO/TKO      1  1:34   1
# 1260  Francis Ngannou    8   0     0  Heavyweight  KO/TKO      1  1:34   0
# 1317  Francis Ngannou    1   0     0  Heavyweight     SUB      1  1:57   0
# ...
